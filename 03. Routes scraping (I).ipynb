# %% [markdown]
# # Scraping the best routes for each destination from Wikiloc.

# %% [markdown]
# Now that we have all mountain passes (both its name and coordinates) we will begin by scraping all road bike routes on **Wikiloc** that match the name of a mountain pass. Our tool of choice will be the web scraping engine **Selenium**.

# %%
#Importing libraries.

import pandas as pd
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

# %%
#Initializing our webdriver (Chrome).

driver = webdriver.Chrome()

# %%
#Logging into Wikiloc.

def login():
    time.sleep(1)
    driver.get('https://es.wikiloc.com/wikiloc/start.do')
    time.sleep(1)
    login_button = driver.find_element_by_class_name('form-control')
    login_button.click()
    login_button.send_keys('username')
    password_button = driver.find_element_by_xpath('//*[@id="password"]')
    password_button.click()
    password_button.send_keys('password')

# %%
#At this point we MUST solve the captcha manually. Once solved we can proceed.

# %%
#Navigating to the search section with our "road bike" filter activated.

def filtro():
    search_bar = driver.find_element_by_xpath('/html/body/header/nav/div/div[1]/div/div')
    search_bar.click()
    time.sleep(1)
    search_bar_open = driver.find_element_by_xpath('/html/body/header/nav/div/div[1]/div/div[1]/input')
    search_bar_open.send_keys('bracons')
    time.sleep(1)
    bracons = driver.find_element_by_xpath('/html/body/header/nav/div/div[1]/div/div[2]/div/ul/div')
    bracons.click()
    time.sleep(1)
    actividad = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[1]/div/div[1]/button')
    actividad.click()
    time.sleep(1)
    selector_actividad = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[1]/div/div[1]/div/div/div/div[1]/div[1]/div/div[2]/div/div[2]/div')
    selector_actividad.click()
    time.sleep(1)
    aplicar_filtro = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[1]/div/div[1]/div/div/div/div[2]/button')
    aplicar_filtro.click() #Selecting the "road bike" filter. Now we're all set to scrape any destination.

# %%
#This function scrapes all relevant data from the found routes and returns it as a list of dictionaries.

def scraper_ruta(puerto):
    listado_dict = []
    element = driver.find_elements_by_class_name('trail-list__wrapper')
    for i in range(len(element)):
        try:
            element[i].click()
            time.sleep(0.3)
            nombre_ruta = driver.find_elements_by_xpath('//*[@id="front"]/div/div/h1')[0].text
            url = driver.current_url
            trailrank = driver.find_elements_by_xpath('//*[@id="front"]/div/div/a')[0].text
            distancia = driver.find_elements_by_xpath('//*[@id="trail-data"]/div[1]/div[1]/a/span[2]')[0].text
            desnivel = driver.find_elements_by_xpath('//*[@id="trail-data"]/div[1]/div[3]/a/span[2]')[0].text
            dificultad = driver.find_elements_by_xpath('//*[@id="trail-data"]/div[1]/div[7]/a/span[2]')[0].text
            fotos = driver.find_elements_by_class_name('trail-photo')
            photo1 = fotos[0].get_attribute('href')
            photo2 = fotos[1].get_attribute('href')
            photo3 = fotos[2].get_attribute('href')
            driver.back()
            time.sleep(0.3)
            element = driver.find_elements_by_class_name('trail-list__wrapper')
            dict_ruta = {'ubicacion': puerto, 'nombre': nombre_ruta, 'trailrank': trailrank,'distancia': distancia, 'desnivel': desnivel,
                         'dificultad': dificultad, 'url': url, 'photo1': photo1, 'photo2': photo2, 'photo3': photo3}
            listado_dict.append(dict_ruta)
        except:
            pass
            driver.back()
            time.sleep(0.5)
            element = driver.find_elements_by_class_name('trail-list__wrapper')
    return listado_dict

# %%
#Defining a function that will search routes for the requested destination.

def buscar_ubicacion(ubicacion):
    time.sleep(0.3)
    driver.find_elements_by_xpath('/html/body/header/nav/div/div[1]/div/div/input')[0].click()
    time.sleep(0.3)
    driver.find_elements_by_xpath('/html/body/header/nav/div/div[1]/div/div[1]/input')[0].send_keys(ubicacion)
    time.sleep(0.5)
    driver.find_element_by_xpath('/html/body/header/nav/div/div[1]/div/div[2]/div/ul/div').click()
    time.sleep(0.5)

# %%
df_puertos = pd.read_csv('df_puertos_final.csv')

# %%
df_puertos.head()
# Out:
#    Unnamed: 0                         puerto provincia  \
# 0           0                    Pico Veleta   Granada
# 1           1                           Iram   Granada
# 2           2                        Angliru  Asturias
# 3           3  Ancares Desde Navia De Suarna      Lugo
# 4           4                    Gamoniteiro  Asturias
#
#                          pueblo  altitud  desnivel  distancia  pendiente  \
# 0  El Purche-Sabinas-Pradollano     3384      2662       46.0        5.7
# 1                    Haza Llana     2845      2080       35.0        5.8
# 2                 Santa Eulalia     1570      1423       18.0        7.0
# 3                  Pan do Zarco     1670      1875       35.0        3.8
# 4               Pola-Cobertoria     1772      1465       15.0        9.0
#
#    coeficiente                                                url
# 0          588  https://www.altimetrias.net/aspbk/verPerfilusu...
# 1          546  https://www.altimetrias.net/aspbk/verPerfilusu...
# 2          528  https://www.altimetrias.net/aspbk/verPuerto.as...
# 3          512  https://www.altimetrias.net/aspbk/verPerfilusu...
# 4          492  https://www.altimetrias.net/aspbk/verPuerto.as...

# %%
#Creating a list containing all mountain pass names.

lista_ubicaciones = df_puertos['puerto']
lista_ubicaciones = lista_ubicaciones.to_list()

# %%
len(lista_ubicaciones)
# Out:
# 1723

# %% [markdown]
# ## Final function

# %%
#This function incorporates all previous functions, iterating through each destination and returning a dataframe of routes.

def scraper_puertos(puertoncios):
    start = time.time()
    lista = []
    for i in puertoncios:
        try:
            buscar_ubicacion(i)
            lista.append(scraper_ruta(i))
        except:
            pass
    df = pd.DataFrame(lista[0])
    for i in lista[1:]:
        df = df.append(i, ignore_index=True)
    stop = time.time() 
    duration = (stop - start) / 60
    print('Minutos:', duration)
    return df

# %%
#Benchmarking our function.

df_test = scraper_puertos(lista_ubicaciones[])
# Out:
# Minutos: 6.923399611314138

# %%
#Creating a dataframe of routes using the function.

df_test.to_csv('df_test.csv', index=False)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ubicacion   86 non-null     object
#  1   nombre      86 non-null     object
#  2   trailrank   86 non-null     object
#  3   distancia   86 non-null     object
#  4   desnivel    86 non-null     object
#  5   dificultad  86 non-null     object
#  6   url         86 non-null     object
#  7   photo1      86 non-null     object
#  8   photo2      86 non-null     object
#  9   photo3      86 non-null     object
# dtypes: object(10)
# memory usage: 6.8+ KB

# %% [markdown]
# ## Cleaning our dataframe

# %% [markdown]
# Now that we've obtained a dataframe of our routes, some data cleaning is needed.

# %%
df1 = pd.read_csv('df_0_50.csv') #Loading all obtained csv files as not to re-run the code.
df2 = pd.read_csv('df_50_100.csv')
df3 = pd.read_csv('df_100_150.csv')
df4 = pd.read_csv('df_150_end.csv')

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True) #Uniting them in a single DF.

# %%
df.drop('Unnamed: 0', inplace=True, axis=1) #Dropping a trash column.

# %%
df.head()
# Out:
#                    ubicacion  \
# 0  SIERRA NEVADA-PICO VELETA
# 1  SIERRA NEVADA-PICO VELETA
# 2  SIERRA NEVADA-PICO VELETA
# 3  SIERRA NEVADA-PICO VELETA
# 4  SIERRA NEVADA-PICO VELETA
#
#                                               nombre  trailrank  distancia  \
# 0    Día 1/2 - Sierra Nevada - Granada - Pico Veleta         64  108,78 km
# 1  Cenes de la vega-Sierra nevada-pico veleta-cen...         43   82,83 km
# 2  Granada- El Purche- Güejar Sierra- Haza Llanas...         35  107,41 km
# 3  Pinos genil - station Sierra nevada - pico de ...         32  125,46 km
# 4  Sierra Nevada hoya de la mora/ Radio telescopi...         20   32,53 km
#
#   desnivel dificultad                                                url  \
# 0  2.914 m          2  https://es.wikiloc.com/rutas-ciclismo/dia-1-2-...
# 1  2.779 m          2  https://es.wikiloc.com/rutas-ciclismo/cenes-de...
# 2  3.341 m          4  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 3  2.130 m          4  https://es.wikiloc.com/rutas-ciclismo/pinos-ge...
# 4  1.201 m          4  https://es.wikiloc.com/rutas-ciclismo/sierra-n...
#
#                                               photo1  \
# 0  https://es.wikiloc.com/rutas-ciclismo/dia-1-2-...
# 1  https://es.wikiloc.com/rutas-ciclismo/cenes-de...
# 2  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 3  https://es.wikiloc.com/rutas-ciclismo/pinos-ge...
# 4  https://es.wikiloc.com/rutas-ciclismo/sierra-n...
#
#                                               photo2  \
# 0  https://es.wikiloc.com/rutas-ciclismo/dia-1-2-...
# 1  https://es.wikiloc.com/rutas-ciclismo/cenes-de...
# 2  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 3  https://es.wikiloc.com/rutas-ciclismo/pinos-ge...
# 4  https://es.wikiloc.com/rutas-ciclismo/sierra-n...
#
#                                               photo3
# 0  https://es.wikiloc.com/rutas-ciclismo/dia-1-2-...
# 1  https://es.wikiloc.com/rutas-ciclismo/cenes-de...
# 2  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 3  https://es.wikiloc.com/rutas-ciclismo/pinos-ge...
# 4  https://es.wikiloc.com/rutas-ciclismo/sierra-n...

# %%
df.to_csv('routes.csv')

# %%
#Assigning a numerical score to the route difficulty.

df.loc[df['dificultad'] == 'Fácil', 'dificultad'] = 1
df.loc[df['dificultad'] == 'Moderado', 'dificultad'] = 2
df.loc[df['dificultad'] == 'Difícil', 'dificultad'] = 3
df.loc[df['dificultad'] == 'Muy difícil', 'dificultad'] = 4
df.loc[df['dificultad'] == 'Sólo expertos', 'dificultad'] = 5

# %%
#We see that we've got 526 locations, 49 less than in our 'altimetrias' dataset. This means that 49 locations didn't have
#routes matching our quality criteria.

df['ubicacion'].value_counts()
# Out:
# EL MEDIANO                   24
# SAN JUAN DE ARTZUAGA         24
# MAS DE LA COSTA              24
# PAJARES                      24
# LA PUEBLA                    24
#                              ..
# BERMIEGO                      1
# LEABURU                       1
# URRUZTIMENDI                  1
# VALLENÓN-CAMPO LAS DANZAS     1
# EMBALSE DE ARTIBA             1
# Name: ubicacion, Length: 526, dtype: int64

# %%
df.sort_values(by=['trailrank'], ascending=False).head(50)
# Out:
#                            ubicacion  \
# 1583                         LA MINA
# 5168                            BECI
# 1584                         LA MINA
# 1585                         LA MINA
# 1587                         LA MINA
# 1586                         LA MINA
# 1588                         LA MINA
# 948                        EL ESCUDO
# 1591                         LA MINA
# 1590                         LA MINA
# 1589                         LA MINA
# 1596                         LA MINA
# 1594                         LA MINA
# 1593                         LA MINA
# 1592                         LA MINA
# 1595                         LA MINA
# 1603                         LA MINA
# 1597                         LA MINA
# 1599                         LA MINA
# 1600                         LA MINA
# 1601                         LA MINA
# 1602                         LA MINA
# 1604                         LA MINA
# 4037                          MOCLÍN
# 1598                         LA MINA
# 693                       EL DORNAJO
# 1119                       EL PURCHE
# 1605                         LA MINA
# 4038                          MOCLÍN
# 1606                         LA MINA
# 2817            BOQUETE DE ZAFARRAYA
# 86    PUERTO CAMACHO-SIERRA DE LÚJAR
# 366                         LA RAGUA
# 2372                VIRGEN DEL VALLE
# 5361                       SANT PERE
# 4882                     PUERTO LOPE
# 4881                     PUERTO LOPE
# 1242                           CÁÑAR
# 4039                          MOCLÍN
# 1253                           CÁÑAR
# 3656                            JOSA
# 1809      MIRADOR DE LA CABRA MONTÉS
# 4893                     PUERTO LOPE
# 5083          SANTO CRISTO DE GARZÓN
# 5225                            JATA
# 3772                            ALEN
# 2747                        SERRABLO
# 418                 RASOS DE PEGUERA
# 4894                     PUERTO LOPE
# 4139                  CERRO MALACARA
#
#                                                  nombre  trailrank  distancia  \
# 1583                     San francisco circular en bici         99   42,05 km
# 5168                     San francisco circular en bici         99   42,05 km
# 1584  Guarne - Llanogrande - La Ceja - Rionegro - Gu...         97   69,53 km
# 1585  CORONANDO el GARBI por la FRONTERA desde Valen...         96      69 km
# 1587       La Cabra por Almuñecar - 8-11-2012 - Granada         95  159,35 km
# 1586        Iznalloz, Pto. Zegri, Colomera - 18-09-2014         95    97,4 km
# 1588                      Villanueva Mesia - 17-02-2015         94  101,46 km
# 948                   Benalua de las Villas - 4-09-2014         93   76,12 km
# 1591    Granada, Guadix y vuelta por Lugros - 5-06-2014         93  140,26 km
# 1590                  Benalua de las Villas - 4-09-2014         93   76,12 km
# 1589  La Cabra y vuelta por Guajares - Granada 24-05...         93  157,12 km
# 1596                     Conchar, Restabal - 13-04-2015         92   68,65 km
# 1594  Agrón, Bermejales, Santa Cruz del Comercio, Br...         92  124,42 km
# 1593         Baños de Alicun de las Torres - 25/05/2014         92   61,55 km
# 1592                           El Mendrugo - 15-02-2015         92  119,08 km
# 1595  El Mendrugo. Pto.Blancares, La Peza, Darro, Mo...         92  126,83 km
# 1603  Granada, Deifontes, Iznalloz, Pto. Zegri, Bena...         91   97,75 km
# 1597                        Moclin, Illora - 25-09-2014         91   93,63 km
# 1599  Granada, Albolote, Atarfe, Santa Fé, La Malahá...         91    57,1 km
# 1600     Pto.Lobo, Beas, Blancares, Guadix - 27-05-2014         91  128,75 km
# 1601  Granada, El Purche, Pinillos, Guejar, Hazallan...         91   72,54 km
# 1602  La Malaha, Escuzar, Ventas, Lachar y vuelta po...         91   69,65 km
# 1604           Bogotá Chirriadísima Ala . Enero de 2016         91   58,59 km
# 4037                        Moclin, Illora - 25-09-2014         91   93,63 km
# 1598  Granada, Purullena, Belerda, Diezma, Granada -...         91  127,24 km
# 693   Granada, El Purche, Pinillos, Guejar, Hazallan...         91   72,54 km
# 1119  Granada, El Purche, Pinillos, Guejar, Hazallan...         91   72,54 km
# 1605  Granada, Illora, Huétor Tajar, Montefrio, Tocó...         90  151,93 km
# 4038       Moclin, Tozar, Illora - Granada - 20-03-2014         90  110,75 km
# 1606  Alhama, Ventas de Zafarraya, Torre del mar, He...         90  222,45 km
# 2817  Alhama, Ventas de Zafarraya, Torre del mar, He...         90  222,45 km
# 86    Granada, Lanjarón, Orgiva, Torvizcón, Contravi...         89  158,02 km
# 366                 Granada, Guadix, puerto de la Ragua         88  199,41 km
# 2372  Lanjarón, Orgiva, Vélez de Benaudalla, Los Gua...         88   65,85 km
# 5361  Transpirenaica-Transpirinenca en bicicleta de ...         87  748,72 km
# 4882                          Montefrio por Puerto Lope         87  125,86 km
# 4881  Santa Fé, Illora, Loja, Ventorros, Montefrio y...         87  156,04 km
# 1242               Granada, Cañar, Granada - 12-01-2014         87  122,16 km
# 4039  Santa Fe, Illora, Tocón, Montefrio, P.Lope, Mo...         87  141,94 km
# 1253     Alhendín, Durcal, Lanjarón, Cañar - 19-04-2015         86  117,61 km
# 3656  Loja y vuelta por Ventorros de San José - 22-0...         86  170,34 km
# 1809  Torrecardela, Guadahortuna, Solera, Est. Cabra...         85   94,65 km
# 4893           Puerto Lope, Mures, Benalua - 11-04-2015         85    90,8 km
# 5083  La Malahá, Escuzar, Ventas, Lachar, Escoznar, ...         85  103,99 km
# 5225  Puerto de Oroel - Jaca - (St. Juan de la Peña)...         85   51,08 km
# 3772  Igualada-Les Coromines-Calaf-Torà-Hostal Nou-E...         84  126,54 km
# 2747  Puerto de Serrablo (Parque Natural de Sierra y...         83  162,97 km
# 418   Pujada als Rasos de Peguera (1.836m.) - Berga....         83   36,27 km
# 4894       Puerto Lope, Montefrio, Huetor Tajar, Illora         82  127,59 km
# 4139  Puerto Malacara por Olivares e Illora y vuelta...         80   84,73 km
#
#       desnivel     dificultad  \
# 1583     528 m              2
# 5168     528 m              2
# 1584     738 m              2
# 1585     787 m              2
# 1587   2.296 m              2
# 1586     942 m              1
# 1588     609 m              2
# 948      814 m              1
# 1591   1.832 m              2
# 1590     814 m              1
# 1589   2.692 m              3
# 1596     920 m              2
# 1594   1.283 m              2
# 1593     450 m              1
# 1592   1.104 m              2
# 1595   1.242 m              2
# 1603     971 m              2
# 1597     969 m              2
# 1599     394 m              2
# 1600   2.132 m              2
# 1601   1.984 m              2
# 1602     488 m              1
# 1604     131 m              1
# 4037     969 m              2
# 1598   1.831 m              2
# 693    1.984 m              2
# 1119   1.984 m              2
# 1605   1.294 m              2
# 4038   1.245 m              2
# 1606   3.549 m              4
# 2817   3.549 m              4
# 86     2.450 m              2
# 366    2.924 m              2
# 2372   1.713 m              2
# 5361  15.853 m              3
# 4882   1.004 m              2
# 4881   1.398 m              2
# 1242   1.719 m              2
# 4039   1.913 m              2
# 1253   1.695 m              2
# 3656   1.623 m              2
# 1809   1.408 m              2
# 4893     922 m              2
# 5083     882 m              2
# 5225     494 m              2
# 3772   1.580 m              3
# 2747   1.967 m  Solo expertos
# 418    1.215 m              3
# 4894   1.011 m              2
# 4139     877 m              3
#
#                                                     url  \
# 1583  https://es.wikiloc.com/rutas-ciclismo/san-fran...
# 5168  https://es.wikiloc.com/rutas-ciclismo/san-fran...
# 1584  https://es.wikiloc.com/rutas-ciclismo/guarne-l...
# 1585  https://es.wikiloc.com/rutas-ciclismo/coronand...
# 1587  https://es.wikiloc.com/rutas-ciclismo/la-cabra...
# 1586  https://es.wikiloc.com/rutas-ciclismo/iznalloz...
# 1588  https://es.wikiloc.com/rutas-ciclismo/villanue...
# 948   https://es.wikiloc.com/rutas-ciclismo/benalua-...
# 1591  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1590  https://es.wikiloc.com/rutas-ciclismo/benalua-...
# 1589  https://es.wikiloc.com/rutas-ciclismo/la-cabra...
# 1596  https://es.wikiloc.com/rutas-ciclismo/conchar-...
# 1594  https://es.wikiloc.com/rutas-ciclismo/agron-be...
# 1593  https://es.wikiloc.com/rutas-ciclismo/banos-de...
# 1592  https://es.wikiloc.com/rutas-ciclismo/el-mendr...
# 1595  https://es.wikiloc.com/rutas-ciclismo/el-mendr...
# 1603  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1597  https://es.wikiloc.com/rutas-ciclismo/moclin-i...
# 1599  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1600  https://es.wikiloc.com/rutas-ciclismo/pto-lobo...
# 1601  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1602  https://es.wikiloc.com/rutas-ciclismo/la-malah...
# 1604  https://es.wikiloc.com/rutas-ciclismo/bogota-c...
# 4037  https://es.wikiloc.com/rutas-ciclismo/moclin-i...
# 1598  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 693   https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1119  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1605  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 4038  https://es.wikiloc.com/rutas-ciclismo/moclin-t...
# 1606  https://es.wikiloc.com/rutas-ciclismo/alhama-v...
# 2817  https://es.wikiloc.com/rutas-ciclismo/alhama-v...
# 86    https://es.wikiloc.com/rutas-ciclismo/granada-...
# 366   https://es.wikiloc.com/rutas-ciclismo/granada-...
# 2372  https://es.wikiloc.com/rutas-ciclismo/lanjaron...
# 5361  https://es.wikiloc.com/rutas-ciclismo/transpir...
# 4882  https://es.wikiloc.com/rutas-ciclismo/montefri...
# 4881  https://es.wikiloc.com/rutas-ciclismo/santa-fe...
# 1242  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 4039  https://es.wikiloc.com/rutas-ciclismo/santa-fe...
# 1253  https://es.wikiloc.com/rutas-ciclismo/alhendin...
# 3656  https://es.wikiloc.com/rutas-ciclismo/loja-y-v...
# 1809  https://es.wikiloc.com/rutas-ciclismo/torrecar...
# 4893  https://es.wikiloc.com/rutas-ciclismo/puerto-l...
# 5083  https://es.wikiloc.com/rutas-ciclismo/la-malah...
# 5225  https://es.wikiloc.com/rutas-ciclismo/puerto-d...
# 3772  https://es.wikiloc.com/rutas-ciclismo/igualada...
# 2747  https://es.wikiloc.com/rutas-ciclismo/puerto-d...
# 418   https://es.wikiloc.com/rutas-ciclismo/pujada-a...
# 4894  https://es.wikiloc.com/rutas-ciclismo/puerto-l...
# 4139  https://es.wikiloc.com/rutas-ciclismo/puerto-m...
#
#                                                  photo1  \
# 1583  https://es.wikiloc.com/rutas-ciclismo/san-fran...
# 5168  https://es.wikiloc.com/rutas-ciclismo/san-fran...
# 1584  https://es.wikiloc.com/rutas-ciclismo/guarne-l...
# 1585  https://es.wikiloc.com/rutas-ciclismo/coronand...
# 1587  https://es.wikiloc.com/rutas-ciclismo/la-cabra...
# 1586  https://es.wikiloc.com/rutas-ciclismo/iznalloz...
# 1588  https://es.wikiloc.com/rutas-ciclismo/villanue...
# 948   https://es.wikiloc.com/rutas-ciclismo/benalua-...
# 1591  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1590  https://es.wikiloc.com/rutas-ciclismo/benalua-...
# 1589  https://es.wikiloc.com/rutas-ciclismo/la-cabra...
# 1596  https://es.wikiloc.com/rutas-ciclismo/conchar-...
# 1594  https://es.wikiloc.com/rutas-ciclismo/agron-be...
# 1593  https://es.wikiloc.com/rutas-ciclismo/banos-de...
# 1592  https://es.wikiloc.com/rutas-ciclismo/el-mendr...
# 1595  https://es.wikiloc.com/rutas-ciclismo/el-mendr...
# 1603  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1597  https://es.wikiloc.com/rutas-ciclismo/moclin-i...
# 1599  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1600  https://es.wikiloc.com/rutas-ciclismo/pto-lobo...
# 1601  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1602  https://es.wikiloc.com/rutas-ciclismo/la-malah...
# 1604  https://es.wikiloc.com/rutas-ciclismo/bogota-c...
# 4037  https://es.wikiloc.com/rutas-ciclismo/moclin-i...
# 1598  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 693   https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1119  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1605  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 4038  https://es.wikiloc.com/rutas-ciclismo/moclin-t...
# 1606  https://es.wikiloc.com/rutas-ciclismo/alhama-v...
# 2817  https://es.wikiloc.com/rutas-ciclismo/alhama-v...
# 86    https://es.wikiloc.com/rutas-ciclismo/granada-...
# 366   https://es.wikiloc.com/rutas-ciclismo/granada-...
# 2372  https://es.wikiloc.com/rutas-ciclismo/lanjaron...
# 5361  https://es.wikiloc.com/rutas-ciclismo/transpir...
# 4882  https://es.wikiloc.com/rutas-ciclismo/montefri...
# 4881  https://es.wikiloc.com/rutas-ciclismo/santa-fe...
# 1242  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 4039  https://es.wikiloc.com/rutas-ciclismo/santa-fe...
# 1253  https://es.wikiloc.com/rutas-ciclismo/alhendin...
# 3656  https://es.wikiloc.com/rutas-ciclismo/loja-y-v...
# 1809  https://es.wikiloc.com/rutas-ciclismo/torrecar...
# 4893  https://es.wikiloc.com/rutas-ciclismo/puerto-l...
# 5083  https://es.wikiloc.com/rutas-ciclismo/la-malah...
# 5225  https://es.wikiloc.com/rutas-ciclismo/puerto-d...
# 3772  https://es.wikiloc.com/rutas-ciclismo/igualada...
# 2747  https://es.wikiloc.com/rutas-ciclismo/puerto-d...
# 418   https://es.wikiloc.com/rutas-ciclismo/pujada-a...
# 4894  https://es.wikiloc.com/rutas-ciclismo/puerto-l...
# 4139  https://es.wikiloc.com/rutas-ciclismo/puerto-m...
#
#                                                  photo2  \
# 1583  https://es.wikiloc.com/rutas-ciclismo/san-fran...
# 5168  https://es.wikiloc.com/rutas-ciclismo/san-fran...
# 1584  https://es.wikiloc.com/rutas-ciclismo/guarne-l...
# 1585  https://es.wikiloc.com/rutas-ciclismo/coronand...
# 1587  https://es.wikiloc.com/rutas-ciclismo/la-cabra...
# 1586  https://es.wikiloc.com/rutas-ciclismo/iznalloz...
# 1588  https://es.wikiloc.com/rutas-ciclismo/villanue...
# 948   https://es.wikiloc.com/rutas-ciclismo/benalua-...
# 1591  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1590  https://es.wikiloc.com/rutas-ciclismo/benalua-...
# 1589  https://es.wikiloc.com/rutas-ciclismo/la-cabra...
# 1596  https://es.wikiloc.com/rutas-ciclismo/conchar-...
# 1594  https://es.wikiloc.com/rutas-ciclismo/agron-be...
# 1593  https://es.wikiloc.com/rutas-ciclismo/banos-de...
# 1592  https://es.wikiloc.com/rutas-ciclismo/el-mendr...
# 1595  https://es.wikiloc.com/rutas-ciclismo/el-mendr...
# 1603  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1597  https://es.wikiloc.com/rutas-ciclismo/moclin-i...
# 1599  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1600  https://es.wikiloc.com/rutas-ciclismo/pto-lobo...
# 1601  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1602  https://es.wikiloc.com/rutas-ciclismo/la-malah...
# 1604  https://es.wikiloc.com/rutas-ciclismo/bogota-c...
# 4037  https://es.wikiloc.com/rutas-ciclismo/moclin-i...
# 1598  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 693   https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1119  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1605  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 4038  https://es.wikiloc.com/rutas-ciclismo/moclin-t...
# 1606  https://es.wikiloc.com/rutas-ciclismo/alhama-v...
# 2817  https://es.wikiloc.com/rutas-ciclismo/alhama-v...
# 86    https://es.wikiloc.com/rutas-ciclismo/granada-...
# 366   https://es.wikiloc.com/rutas-ciclismo/granada-...
# 2372  https://es.wikiloc.com/rutas-ciclismo/lanjaron...
# 5361  https://es.wikiloc.com/rutas-ciclismo/transpir...
# 4882  https://es.wikiloc.com/rutas-ciclismo/montefri...
# 4881  https://es.wikiloc.com/rutas-ciclismo/santa-fe...
# 1242  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 4039  https://es.wikiloc.com/rutas-ciclismo/santa-fe...
# 1253  https://es.wikiloc.com/rutas-ciclismo/alhendin...
# 3656  https://es.wikiloc.com/rutas-ciclismo/loja-y-v...
# 1809  https://es.wikiloc.com/rutas-ciclismo/torrecar...
# 4893  https://es.wikiloc.com/rutas-ciclismo/puerto-l...
# 5083  https://es.wikiloc.com/rutas-ciclismo/la-malah...
# 5225  https://es.wikiloc.com/rutas-ciclismo/puerto-d...
# 3772  https://es.wikiloc.com/rutas-ciclismo/igualada...
# 2747  https://es.wikiloc.com/rutas-ciclismo/puerto-d...
# 418   https://es.wikiloc.com/rutas-ciclismo/pujada-a...
# 4894  https://es.wikiloc.com/rutas-ciclismo/puerto-l...
# 4139  https://es.wikiloc.com/rutas-ciclismo/puerto-m...
#
#                                                  photo3
# 1583  https://es.wikiloc.com/rutas-ciclismo/san-fran...
# 5168  https://es.wikiloc.com/rutas-ciclismo/san-fran...
# 1584  https://es.wikiloc.com/rutas-ciclismo/guarne-l...
# 1585  https://es.wikiloc.com/rutas-ciclismo/coronand...
# 1587  https://es.wikiloc.com/rutas-ciclismo/la-cabra...
# 1586  https://es.wikiloc.com/rutas-ciclismo/iznalloz...
# 1588  https://es.wikiloc.com/rutas-ciclismo/villanue...
# 948   https://es.wikiloc.com/rutas-ciclismo/benalua-...
# 1591  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1590  https://es.wikiloc.com/rutas-ciclismo/benalua-...
# 1589  https://es.wikiloc.com/rutas-ciclismo/la-cabra...
# 1596  https://es.wikiloc.com/rutas-ciclismo/conchar-...
# 1594  https://es.wikiloc.com/rutas-ciclismo/agron-be...
# 1593  https://es.wikiloc.com/rutas-ciclismo/banos-de...
# 1592  https://es.wikiloc.com/rutas-ciclismo/el-mendr...
# 1595  https://es.wikiloc.com/rutas-ciclismo/el-mendr...
# 1603  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1597  https://es.wikiloc.com/rutas-ciclismo/moclin-i...
# 1599  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1600  https://es.wikiloc.com/rutas-ciclismo/pto-lobo...
# 1601  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1602  https://es.wikiloc.com/rutas-ciclismo/la-malah...
# 1604  https://es.wikiloc.com/rutas-ciclismo/bogota-c...
# 4037  https://es.wikiloc.com/rutas-ciclismo/moclin-i...
# 1598  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 693   https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1119  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 1605  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 4038  https://es.wikiloc.com/rutas-ciclismo/moclin-t...
# 1606  https://es.wikiloc.com/rutas-ciclismo/alhama-v...
# 2817  https://es.wikiloc.com/rutas-ciclismo/alhama-v...
# 86    https://es.wikiloc.com/rutas-ciclismo/granada-...
# 366   https://es.wikiloc.com/rutas-ciclismo/granada-...
# 2372  https://es.wikiloc.com/rutas-ciclismo/lanjaron...
# 5361  https://es.wikiloc.com/rutas-ciclismo/transpir...
# 4882  https://es.wikiloc.com/rutas-ciclismo/montefri...
# 4881  https://es.wikiloc.com/rutas-ciclismo/santa-fe...
# 1242  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 4039  https://es.wikiloc.com/rutas-ciclismo/santa-fe...
# 1253  https://es.wikiloc.com/rutas-ciclismo/alhendin...
# 3656  https://es.wikiloc.com/rutas-ciclismo/loja-y-v...
# 1809  https://es.wikiloc.com/rutas-ciclismo/torrecar...
# 4893  https://es.wikiloc.com/rutas-ciclismo/puerto-l...
# 5083  https://es.wikiloc.com/rutas-ciclismo/la-malah...
# 5225  https://es.wikiloc.com/rutas-ciclismo/puerto-d...
# 3772  https://es.wikiloc.com/rutas-ciclismo/igualada...
# 2747  https://es.wikiloc.com/rutas-ciclismo/puerto-d...
# 418   https://es.wikiloc.com/rutas-ciclismo/pujada-a...
# 4894  https://es.wikiloc.com/rutas-ciclismo/puerto-l...
# 4139  https://es.wikiloc.com/rutas-ciclismo/puerto-m...

# %% [markdown]
# **<div align="right">Ironhack DA PT 2021</div>**
#
# **<div align="right">Xavier Esteban</div>**
