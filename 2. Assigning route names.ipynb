# %% [markdown]
# # Assigning custom names to our routes

# %% [markdown]
# Since our *routes* dataframe contains parsed data from a wide variety of sources the route names can vary greatly both in accuracy and grammar. To solve this issue in this notebook we will be generating new route names based on the mountain passes and town that each route visits.

# %%
import pandas as pd

# %%
#Importing our routes dataframe.

routes = pd.read_csv('routes_1607_819.csv')

# %%
routes.head()
# Out:
#      ID                                               name  ccaa  province  \
# 0   923          ANGLIRU, CIRCULAR DESDE LA PLAZA, TEVERGA   NaN       NaN
# 1  5611  Pola de Lena, Cobertoria, Gamoniteiro, Tenebre...   NaN       NaN
# 2  5490                       PEÑA ESCRITA (POR ALMUÑECAR)   NaN       NaN
# 3   881                                 Ancares-Pandozarco   NaN       NaN
# 4  5618  POLA DE LENA - PUERTO DE PAJARES - CUITU NEGRU...   NaN       NaN
#
#                    start               midpoint  trailrank  distance  \
# 0  [-6.101982,43.158859]  [-5.939921,43.235847]         67       124
# 1    [-5.8297,43.155729]  [-5.929957,43.288199]         51       118
# 2  [-3.743127,36.734975]  [-3.762692,36.818439]         42        45
# 3  [-7.157974,42.852246]  [-6.844199,42.889535]         55       130
# 4  [-5.806177,43.128166]  [-5.829091,43.083221]         42       121
#
#    gradient  min_alt  max_alt  municipality mountain_passes_ids  \
# 0      3476      101     1566           NaN                 [0]
# 1      4234      102     1700           NaN     [0, 1, 84, 131]
# 2      1481        6     1191           NaN                 [2]
# 3      2861      289     1651           NaN      [3, 182, 1109]
# 4      2917      344     1824           NaN    [4, 51, 69, 438]
#
#    municipalities_ids
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %% [markdown]
# # Adding municipalities to each route

# %% [markdown]
# To create a better naming scheme we need to know which towns are near every route. For this purpose we will be using our *towns* dataframe after filtering (201 destinations).

# %%
towns = pd.read_csv('towns_1907_201.csv')

# %%
towns.head()
# Out:
#      ID municipality                  ccaa   province  \
# 0   884    Barcelona              Cataluña  Barcelona
# 1  7257     València  Comunitat Valenciana   Valencia
# 2  4547       Málaga             Andalucía     Málaga
# 3  4613       Murcia      Región de Murcia     Murcia
# 4   151     Alicante  Comunitat Valenciana   Alicante
#
#    municipality_inhabitants  geographic_area     radius  routes_number  \
# 0                   1664182       100.764400   5.663411              4
# 1                    800215       139.268700   6.658115              9
# 2                    578460       395.706900  11.223062             10
# 3                    459403       885.114900  16.785117              7
# 4                    337482       201.265845   8.004046              9
#
#                                           routes_ids  mountain_passes_ids  \
# 0                           [1292, 1732, 6228, 8149]                  NaN
# 1  [528, 1469, 1472, 2478, 5225, 7040, 7231, 7734...                  NaN
# 2  [2933, 4541, 4546, 5035, 5997, 5998, 8379, 841...                  NaN
# 3          [691, 1691, 6089, 6769, 7049, 8099, 8196]                  NaN
# 4  [621, 629, 647, 680, 1469, 3189, 8145, 9500, 9...                  NaN
#
#                       coords                 coords_MDB
# 0   (41.38424664,2.17634927)   [2.17634927,41.38424664]
# 1  (39.47534441,-0.37565717)  [-0.37565717,39.47534441]
# 2  (36.72034267,-4.41997511)  [-4.41997511,36.72034267]
# 3   (37.98436361,-1.1285408)   [-1.1285408,37.98436361]
# 4   (38.34548705,-0.4831832)   [-0.4831832,38.34548705]

# %%
#We will be using nested loops to add each town ID to the routes dataframe.

for i in range(len(routes)):
    town_list = []
    for n in range(len(towns)):
        for p in eval(towns['routes_ids'].iloc[n]):
            if p == routes['ID'].iloc[i]:
                town_list.append(towns['ID'].iloc[n])
    routes['municipalities_ids'].iloc[i] = str(town_list)
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
routes.head()
# Out:
#      ID                                               name  ccaa  province  \
# 0   923          ANGLIRU, CIRCULAR DESDE LA PLAZA, TEVERGA   NaN       NaN
# 1  5611  Pola de Lena, Cobertoria, Gamoniteiro, Tenebre...   NaN       NaN
# 3   881                                 Ancares-Pandozarco   NaN       NaN
# 4  5618  POLA DE LENA - PUERTO DE PAJARES - CUITU NEGRU...   NaN       NaN
# 5  3467  Granada, Lanjarón, Orgiva, Torvizcón, Contravi...   NaN       NaN
#
#                    start               midpoint  trailrank  distance  \
# 0  [-6.101982,43.158859]  [-5.939921,43.235847]         67       124
# 1    [-5.8297,43.155729]  [-5.929957,43.288199]         51       118
# 3  [-7.157974,42.852246]  [-6.844199,42.889535]         55       130
# 4  [-5.806177,43.128166]  [-5.829091,43.083221]         42       121
# 5  [-3.609443,37.156292]  [-3.275512,36.854694]         89       158
#
#    gradient  min_alt  max_alt  municipality mountain_passes_ids  \
# 0      3476      101     1566           NaN                 [0]
# 1      4234      102     1700           NaN     [0, 1, 84, 131]
# 3      2861      289     1651           NaN      [3, 182, 1109]
# 4      2917      344     1824           NaN    [4, 51, 69, 438]
# 5      2450      242     1186           NaN             [5, 13]
#
#          municipalities_ids
# 0  [5039, 5027, 5020, 5067]
# 1        [5039, 5027, 5067]
# 3              [4245, 5022]
# 4                    [5027]
# 5        [2747, 2806, 2818]

# %%
#Deleting routes with no towns that match our final destinations.

routes = routes[routes['municipalities_ids'] != '[]']

# %%
#We're down to 636 routes.

routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 636 entries, 0 to 818
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   636 non-null    int64
#  1   name                 636 non-null    object
#  2   ccaa                 0 non-null      float64
#  3   province             0 non-null      float64
#  4   start                636 non-null    object
#  5   midpoint             636 non-null    object
#  6   trailrank            636 non-null    int64
#  7   distance             636 non-null    int64
#  8   gradient             636 non-null    int64
#  9   min_alt              636 non-null    int64
#  10  max_alt              636 non-null    int64
#  11  municipality         0 non-null      float64
#  12  mountain_passes_ids  636 non-null    object
#  13  municipalities_ids   636 non-null    object
# dtypes: float64(3), int64(6), object(5)
# memory usage: 74.5+ KB

# %% [markdown]
# # Creating a function that re-names our routes

# %% [markdown]
# Now that we have all mountain passes and towns that each route visits we can build a nice naming structure. This naming schema must meet the following criteria:
#
# 1. Mention all mountain passes visited (up to 2).
# 2. Name all towns that have access to this route (up to 2).
# 3. Make sense gramatically.
#
#
# The schema will vary depending on the number of ports and towns:
#
# **1 port 1 town:** *port* por *town*.
#
# **1 port 2 towns:** *port1* por *town1* y *town2*.
#
# **2 ports 1 town:** *port1* y *port2* por *town*.
#
# **2 ports 2 towns:** *port1* y *port2* por *town1* y *town2*.
#
# **> 2 ports > 2 towns:** *port1* y *port2* por *town1* y *town2*..

# %% [markdown]
# ## Importing our dataframes

# %% [markdown]
# We are now using a smaller *towns* dataframe since we filtered the destinations in notebook 4.

# %%
routes = pd.read_csv('routes_1607_819.csv')

# %%
towns = pd.read_csv('towns_1907_201.csv')

# %%
routes.head(1)
# Out:
#     ID                                       name  ccaa  province  \
# 0  923  ANGLIRU, CIRCULAR DESDE LA PLAZA, TEVERGA   NaN       NaN
#
#                    start               midpoint  trailrank  distance  \
# 0  [-6.101982,43.158859]  [-5.939921,43.235847]         67       124
#
#    gradient  min_alt  max_alt  municipality mountain_passes_ids  \
# 0      3476      101     1566           NaN                 [0]
#
#          municipalities_ids
# 0  [5039, 5027, 5020, 5067]

# %%
towns.head(1)
# Out:
#     ID municipality      ccaa   province  municipality_inhabitants  \
# 0  884    Barcelona  Cataluña  Barcelona                   1664182
#
#    geographic_area    radius  routes_number                routes_ids  \
# 0         100.7644  5.663411              4  [1292, 1732, 6228, 8149]
#
#    mountain_passes_ids                    coords                coords_MDB
# 0                  NaN  (41.38424664,2.17634927)  [2.17634927,41.38424664]

# %% [markdown]
# ## Adding municipalities to each route

# %% [markdown]
# We will simply be using the previous loop to add municipalities to each route.

# %%
for i in range(len(routes)):
    town_list = []
    for n in range(len(towns)):
        for p in eval(towns['routes_ids'].iloc[n]):
            if p == routes['ID'].iloc[i]:
                town_list.append(towns['ID'].iloc[n])
    routes['municipalities_ids'].iloc[i] = str(town_list)
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
routes.head(1)
# Out:
#     ID                                       name  ccaa  province  \
# 0  923  ANGLIRU, CIRCULAR DESDE LA PLAZA, TEVERGA   NaN       NaN
#
#                    start               midpoint  trailrank  distance  \
# 0  [-6.101982,43.158859]  [-5.939921,43.235847]         67       124
#
#    gradient  min_alt  max_alt  municipality mountain_passes_ids  \
# 0      3476      101     1566           NaN                 [0]
#
#          municipalities_ids
# 0  [5039, 5027, 5020, 5067]

# %%
ports = pd.read_csv('puertos_i.csv')

# %%
ports.head(1)
# Out:
#    ID     name  province   municipality  altitude  gradient  distance  \
# 0   0  Angliru  Asturias  Santa Eulalia      1570      1423      18.0
#
#    mountain_slope  technical_difficulty  \
# 0             7.0                   528
#
#                                                  url           peak_coords  \
# 0  https://www.altimetrias.net/aspbk/verPuerto.as...  [-5.94178,43.221596]
#
#    photo
# 0    NaN

# %% [markdown]
# ## Creating the function

# %% [markdown]
# Our job will be made easier by the use of two separate functions. The first one will take every route and generate a list of ports and towns, while the second one will generate a name based on those lists and return it.

# %%
#Defining our first function:

def name_creator(routes, towns, ports):
    """
    Input : dataframes of routes, towns and ports.
    
    Output: dataframe with the custom names containing both ports and towns.
    
    """
    routes = routes.copy()
    for i in range(len(routes)): #Iterating through each route.
        list_ports = eval(routes['mountain_passes_ids'].iloc[i]) #Generating a list of ports.
        list_towns = eval(routes['municipalities_ids'].iloc[i]) #The same procedure for the towns.
        routes['name'].iloc[i] = composer(list_ports, list_towns, towns, ports) #Assigning the name returned by the second function.
        
    return routes

# %%
#Defining the second one:

def composer(list_ports, list_towns, towns, ports):
    """
    Input : two lists of port and town IDs, towns and ports dataframes.
    
    Output: custom name containing those ports and towns.
    
    """
    if len(list_ports) == 1 and len(list_towns) == 1: #First case, 1 port 1 town.
        return ports[ports['ID'] == list_ports[0]]['name'].iloc[0] + ' por ' + towns[towns['ID'] == list_towns[0]]['municipality'].iloc[0] + '.'
    elif len(list_ports) == 1 and len(list_towns) == 2: 
        return ports[ports['ID'] == list_ports[0]]['name'].iloc[0] + ' por ' + towns[towns['ID'] == list_towns[0]]['municipality'].iloc[0] + ' y ' + towns[towns['ID'] == list_towns[1]]['municipality'].iloc[0] + '.'
    elif len(list_ports) == 1 and len(list_towns) > 2: 
        return ports[ports['ID'] == list_ports[0]]['name'].iloc[0] + ' por ' + towns[towns['ID'] == list_towns[0]]['municipality'].iloc[0] + ' y ' + towns[towns['ID'] == list_towns[1]]['municipality'].iloc[0] + '.'
    elif len(list_ports) == 2 and len(list_towns) == 1: #Second case, 2 ports 1 town.
        return ports[ports['ID'] == list_ports[0]]['name'].iloc[0] + ' y ' + ports[ports['ID'] == list_ports[1]]['name'].iloc[0] + ' por ' + towns[towns['ID'] == list_towns[0]]['municipality'].iloc[0] + '.'
    elif len(list_ports) > 2 and len(list_towns) == 1: #Second case, 2 ports 1 town.
        return ports[ports['ID'] == list_ports[0]]['name'].iloc[0] + ' y ' + ports[ports['ID'] == list_ports[1]]['name'].iloc[0] + ' por ' + towns[towns['ID'] == list_towns[0]]['municipality'].iloc[0] + '.'
    elif len(list_ports) > 2 and len(list_towns) > 2: #Third case, 2 ports 2 towns (etc).
        return ports[ports['ID'] == list_ports[0]]['name'].iloc[0] + ' y ' + ports[ports['ID'] == list_ports[1]]['name'].iloc[0] + ' por ' + towns[towns['ID'] == list_towns[0]]['municipality'].iloc[0] + ' y ' + towns[towns['ID'] == list_towns[1]]['municipality'].iloc[0] + '.'
    elif len(list_ports) > 2 and len(list_towns) == 2: #Third case, 2 ports 2 towns (etc).
        return ports[ports['ID'] == list_ports[0]]['name'].iloc[0] + ' y ' + ports[ports['ID'] == list_ports[1]]['name'].iloc[0] + ' por ' + towns[towns['ID'] == list_towns[0]]['municipality'].iloc[0] + ' y ' + towns[towns['ID'] == list_towns[1]]['municipality'].iloc[0] + '.'
    elif len(list_ports) == 2 and len(list_towns) > 2: #Third case, 2 ports 2 towns (etc).
        return ports[ports['ID'] == list_ports[0]]['name'].iloc[0] + ' y ' + ports[ports['ID'] == list_ports[1]]['name'].iloc[0] + ' por ' + towns[towns['ID'] == list_towns[0]]['municipality'].iloc[0] + ' y ' + towns[towns['ID'] == list_towns[1]]['municipality'].iloc[0] + '.'
    elif len(list_ports) == 2 and len(list_towns) == 2: #Third case, 2 ports 2 towns (etc).
        return ports[ports['ID'] == list_ports[0]]['name'].iloc[0] + ' y ' + ports[ports['ID'] == list_ports[1]]['name'].iloc[0] + ' por ' + towns[towns['ID'] == list_towns[0]]['municipality'].iloc[0] + ' y ' + towns[towns['ID'] == list_towns[1]]['municipality'].iloc[0] + '.'

# %%
test = name_creator(routes, towns, ports)
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
test.head()
# Out:
#      ID                                               name  ccaa  province  \
# 0   923                         Angliru por Oviedo y Lena.   NaN       NaN
# 1  5611           Angliru y Gamoniteiro por Oviedo y Lena.   NaN       NaN
# 3   881  Ancares y Sierra De Morela por Cervantes y Ibias.   NaN       NaN
# 4  5618         Pajares-Cuitu Negru y La Cubilla por Lena.   NaN       NaN
# 5  3467  Puerto Camacho y Haza Del Lino por Dúrcal y Ór...   NaN       NaN
#
#                    start               midpoint  trailrank  distance  \
# 0  [-6.101982,43.158859]  [-5.939921,43.235847]         67       124
# 1    [-5.8297,43.155729]  [-5.929957,43.288199]         51       118
# 3  [-7.157974,42.852246]  [-6.844199,42.889535]         55       130
# 4  [-5.806177,43.128166]  [-5.829091,43.083221]         42       121
# 5  [-3.609443,37.156292]  [-3.275512,36.854694]         89       158
#
#    gradient  min_alt  max_alt  municipality mountain_passes_ids  \
# 0      3476      101     1566           NaN                 [0]
# 1      4234      102     1700           NaN     [0, 1, 84, 131]
# 3      2861      289     1651           NaN      [3, 182, 1109]
# 4      2917      344     1824           NaN    [4, 51, 69, 438]
# 5      2450      242     1186           NaN             [5, 13]
#
#          municipalities_ids
# 0  [5039, 5027, 5020, 5067]
# 1        [5039, 5027, 5067]
# 3              [4245, 5022]
# 4                    [5027]
# 5        [2747, 2806, 2818]

# %%
#Visually inspecting the names. Everything seems to be in order! We have succesfully generated all names.

test_list = test['name'].tolist()
test_list
# Out:
# ['Angliru por Oviedo y Lena.',
#  'Angliru y Gamoniteiro por Oviedo y Lena.',
#  'Ancares y Sierra De Morela por Cervantes y Ibias.',
#  'Pajares-Cuitu Negru y La Cubilla por Lena.',
#  'Puerto Camacho y Haza Del Lino por Dúrcal y Órgiva.',
#  'Morredero - Portillinos y Fonte Da Cova-Collada Trevinca por Ponferrada y O Barco de Valdeorras.',
#  'Navacerrada-Bola Del Mundo y Morcuera por Rascafría.',
#  'Mont Caro y Fredes por La Sénia y Valderrobres.',
#  'Salto De La Cabra y Fuente Dé por Potes.',
#  'Calar Alto y Velefique-Tetica De Bacares por Gérgal.',
#  'Carrascoy por Murcia y Alhama de Murcia.',
#  'Oiz y Monte Oiz por Durango.',
#  'Haza Del Lino por Motril y Dúrcal.',
#  'Peñas Blancas-Los Reales y Encinas Borrachas por Estepona y Ronda.',
#  'Calar Alto y Velefique-Tetica De Bacares por Tíjola y Gérgal.',
#  'Pradell y Josa por Berga.',
#  'Fonte Da Cova-Collada Trevinca y Fonte Da Cova por O Barco de Valdeorras.',
#  'Turó De L´Home por Sant Celoni.',
#  'La Panadera por Jaén y Martos.',
#  'Sierra De Bernia por Alicante y Benidorm.',
#  'La Ragua y Puerto De La Ragua por Guadix.',
#  'Ibañeta-Ortzanzurieta y Artesiaga por Baztan y Esteribar.',
#  'Pagolar y Altube por Vitoria-Gasteiz y Zuia.',
#  'Rasos De Peguera por Berga.',
#  'San Lorenzo y Maravio por Grado y Teverga.',
#  'Calar Alto y Venta Luisa - Calar Alto por Tíjola y Gérgal.',
#  'Lagos De Covadonga por Cangas de Onís.',
#  'Morredero - Portillinos y Peña Aguda-Llano De Las Ovejas por Ponferrada.',
#  'Morrón De Espuña-Collado Bermejo por Alhama de Murcia.',
#  'Picón Del Fraile y Lunada por Medina de Pomar y Espinosa de los Monteros.',
#  'El Yelmo por Santiago-Pontones.',
#  'Moncalvillo por Nájera.',
#  'Lagunas De Neila y Lagunas De Neila por Covaleda.',
#  'San Lorenzo y La Farrapona por Villablino y Teverga.',
#  'Azurki y Ixua por Azkoitia.',
#  'El Boyar - Las Palomas y Las Palomas por Ronda y Olvera.',
#  "Collfred y Bracons por La Vall d'en Bas.",
#  'San Glorio y Piedrasluengas por Potes y Velilla del Río Carrión.',
#  'La Cubilla y Pajares por Lena.',
#  'Mondúver y Montdúver por València y Alzira.',
#  'Collao Espina y Lunada por Ramales de la Victoria y Espinosa de los Monteros.',
#  'Picón Blanco y El Cabrio por Zalla y Valle de Mena.',
#  'Trevélez por Dúrcal y Órgiva.',
#  'Mas De La Costa y El Colladico por Onda y Llucena.',
#  'Lunada y Collado De Asón - La Sía por Espinosa de los Monteros.',
#  'Maravio y Marabio por Oviedo y Grado.',
#  'Lunada y Collado De Asón - La Sía por Espinosa de los Monteros.',
#  'El Escudo por Reinosa.',
#  'Torcal De Antequera y La Joya por Málaga y Antequera.',
#  'Calar Alto y Venta Luisa - Calar Alto por Gérgal.',
#  'Cruz De La Demanda por Ezcaray.',
#  'Collada Llomena y Amieva por Cangas de Onís y Caso.',
#  'Pajares y Millaró De La Tercia por La Robla.',
#  'San Rafael-Valdelinares y Peñarroya por Mora de Rubielos.',
#  'Samiño y Gorla por Azkoitia.',
#  'El Peñón por Puebla de Sanabria.',
#  'Calar Alto y Velefique-Tetica De Bacares por Tíjola y Gérgal.',
#  'Cruz De Linares y San Esteban De Las Cruces por Oviedo y Siero.',
#  'Foncebadón-Cruz De Ferro por Ponferrada.',
#  'Allanadas Del Santo por Jaén.',
#  'Peña Cabarga y Cruz De Usaño por Ribamontán al Monte.',
#  'Pajares y La Cobertoria por Lena y Teverga.',
#  'El León y Boquete De Zafarraya por Málaga y Vélez-Málaga.',
#  'Piedrasluengas por Potes.',
#  'Turó De L´Home y Santa Fe Del Montseny por Sant Celoni.',
#  'San Lorenzo y Somiedo por Villablino y Teverga.',
#  'Serra Gelada por Benidorm.',
#  'San Glorio y El Pontón - Panderrueda por Cangas de Onís y Potes.',
#  'La Borriqueta por Yeste y Nerpio.',
#  'Iroite y Enxa por Boiro y Noia.',
#  'Desierto Las Palmas-Monte Bartolo y Desierto De Las Palmas por Castelló de la Plana y Cabanes.',
#  'Xorret De Catí por Alicante y Castalla.',
#  'Honduras y Piornal por Jaraíz de la Vera y Hervás.',
#  "Bracons por Vic y La Vall d'en Bas.",
#  'Xiabre por Pontevedra.',
#  'Leitariegos por Cangas del Narcea y Villablino.',
#  'El León y La Mina por Málaga y Colmenar.',
#  'El León y Santopitar por Málaga y Vélez-Málaga.',
#  'Presa de Sallente por Tremp.',
#  'Golobar por Reinosa y Aguilar de Campoo.',
#  'Vidré-Vistabella y Coll Del Vidre por València y Sagunto.',
#  'Mijares y Pedro Bernardo por Casavieja y Burgohondo.',
#  'Navapelegrín y Navacerrada por Moralzarzal.',
#  'La Quesera y La Quesera por Riaza.',
#  'La Quesera y La Quesera por Riaza.',
#  'El Boyar - Las Palomas y Las Palomas por Grazalema.',
#  'Pico Del Águila por Huesca.',
#  'Urkiola y Dima por Durango y Etxebarri.',
#  'Peñalba De Santiago por Ponferrada.',
#  'Mirador De La Cabra Montés por Motril y Dúrcal.',
#  'Erlaitz-Castillo Del Inglés y Bianditz por Donostia y Irun.',
#  'Honduras y Portillo De Las Batuecas por Jaraíz de la Vera y Hervás.',
#  'Portalet y Somport por Jaca y Sabiñánigo.',
#  'Turó De L´Home y Santa Fe Del Montseny por Sant Celoni.',
#  'Angliru y El Cordal por Lena.',
#  'Collado De Asón - La Sía y Los Tornos por Ramales de la Victoria y Espinosa de los Monteros.',
#  'El Madroño y Puerto Del Madroño por Ronda y Yunquera.',
#  'El Piélago y El Piélago por Casavieja.',
#  'El Fito por Cangas de Onís.',
#  'Peña Negra y Chía por Piedrahíta.',
#  'Palombera por Torrelavega y Reinosa.',
#  'Oiz y Iturzuri por Durango.',
#  'La Centenera y Nogal Del Barranco por Arenas de San Pedro.',
#  'El Purche y La Alfaguara por Albolote.',
#  'Orduña por Amurrio.',
#  'Colladiella y La Colladiella por Laviana y Lena.',
#  'Campello-Portixol y Beneixama por Ontinyent y Villena.',
#  'Boí-Taüll y Presa De Cavallers por La Vall de Boí.',
#  'Morcuera y Navacerrada por Moralzarzal y Soto del Real.',
#  'Mirador De Ézaro y As Paxareiras por Carnota y Mazaricos.',
#  'Bagordi-Arrateketa y Aniz por Baztan.',
#  'Gaucín y El Espino por Estepona y Cortes de la Frontera.',
#  'Artesiaga y Aniz por Baztan y Esteribar.',
#  'Coto Redondo por Pontevedra.',
#  'Morcuera y Navacerrada por Rascafría.',
#  'Lunada y Collado De Asón - La Sía por Espinosa de los Monteros.',
#  'Abantos y Santa María De La Alameda por San Lorenzo de El Escorial.',
#  'O Poio y Piedrafita por Ponferrada y Villafranca del Bierzo.',
#  'Morredero - Portillinos y Peña Aguda-Llano De Las Ovejas por Ponferrada.',
#  'Cumbres Verdes por Albolote.',
#  'Mijares y La Centenera por Arenas de San Pedro y Burgohondo.',
#  'Paso De Los Lobos-Peña De Francia y Peña De Francia por La Alberca.',
#  'Cruz De La Demanda y Valdezcaray-Collado De Las Tres Cruces por Ezcaray.',
#  'El Espino y Encinas Borrachas por Málaga y Ronda.',
#  ' El Vivero - Ganguren y San Pelayo por Gernika-Lumo y Bermeo.',
#  'Herrera y Zaldiaran por Vitoria-Gasteiz.',
#  'Bikotx-Gane y Altube por Durango y Gernika-Lumo.',
#  'Las Viniegras por Covaleda.',
#  'Elosua - Gorla y Jaizkibel por Donostia y Irun.',
#  'Mendibil (Argalario) y Humaran por Zalla.',
#  'Ancares y Sierra De Morela por Cervantes y Ibias.',
#  'Os Forcados por Boiro.',
#  'Almáchar y Alto De Moclinejo por Vélez-Málaga.',
#  'Santiagomendi y Fuerte De San Marcos por Donostia.',
#  'Javalambre y Javalambre (Pico) por Mora de Rubielos.',
#  'Serrablo por Jaca y Sabiñánigo.',
#  'Portalet y Somport por Jaca y Sabiñánigo.',
#  'Iroite y Enxa por Noia y Carnota.',
#  'Azurki y Endoia por Zarautz y Azkoitia.',
#  'Boquete De Zafarraya y El Sol por Loja y Albolote.',
#  'Bianditz y Jaizkibel por Donostia y Irun.',
#  'Laguna Negra y Santa Inés por Covaleda.',
#  'El Mediano y Arrebatacapas por El Tiemblo.',
#  'Santa Marina por Oyón-Oion.',
#  'Peñas Negras - La Asturiana y Peñas Negras por Zalla.',
#  'Andatzarrate-Iturriotz y Aia por Zarautz.',
#  'Piornal por Jaraíz de la Vera.',
#  'Honduras y Tornavacas por Hervás.',
#  'Paresi y San Pelayo por Bermeo.',
#  'El Boyar - Las Palomas y Las Palomas por Grazalema.',
#  'Morcuera y Navafría por Soto del Real y Rascafría.',
#  'Venta La Gloria por Málaga y Almogía.',
#  'Cotefablo por Sabiñánigo.',
#  'Santopitar y Almáchar por Málaga.',
#  'Peña Negra y Chía por Piedrahíta.',
#  'Ubal por Ramales de la Victoria.',
#  'Morcuera y Navacerrada por Moralzarzal y Soto del Real.',
#  'Ermita De Los Tres Juanes por Albolote.',
#  'Peñón De Algámitas y Puerto Del Zamorano por Morón de la Frontera y Olvera.',
#  'San Juan De La Peña por Jaca.',
#  'Ancares y Campa De Laviadas por A Fonsagrada y Cervantes.',
#  'Erlaitz-Castillo Del Inglés y Castillo Del Inglés por Donostia y Irun.',
#  'Segura De La Sierra y El Bellotar por Siles.',
#  'Ancares y O Portelo-Comeal por Villafranca del Bierzo y Ibias.',
#  'Marjana por Llíria.',
#  'Puerto Camacho y Conjuros por Motril y Órgiva.',
#  'Uriondo por Etxebarri.',
#  'El Peñón y Laguna De Los Peces por Puebla de Sanabria.',
#  'Azpirotz y Garate por Donostia y Zarautz.',
#  'Prado Grande por Órgiva.',
#  'Las Albuñuelas por Dúrcal.',
#  'El Pontón - Panderrueda y Panderrueda por Cangas de Onís.',
#  'Navalmoral y Arrebatacapas por El Tiemblo y Burgohondo.',
#  'Las Erillas y Serranillos por Arenas de San Pedro.',
#  'Soplao. El y Carmona por Cabezón de la Sal.',
#  'Arantzazu por Arrasate.',
#  'La Matanela y Trascampo por Reinosa y Corvera de Toranzo.',
#  'Urkizu por Tolosa.',
#  'Bel por La Sénia y Morella.',
#  'Bianditz y Jaizkibel por Donostia y Irun.',
#  'Boquete De Zafarraya y El Sol por Loja y Albolote.',
#  'Pradell y Rasos De Peguera por Berga.',
#  'El Hontanar y Collado Calderón por Ademuz.',
#  'Orduña y Peña Angulo por Etxebarri y Amurrio.',
#  'Boí-Taüll y Presa De Cavallers por La Vall de Boí.',
#  'La Aldea - Bernedo por Oyón-Oion y Campezo.',
#  'Peña Ranero y La Escrita por Zalla.',
#  'Sancho Leza por Oyón-Oion.',
#  'Boí-Taüll y Presa De Cavallers por La Vall de Boí.',
#  'Castillo de San Julián y Cabo Tiñoso por Cartagena.',
#  'Santa Teodosia y Urbasa por Altsasu y Agurain.',
#  'Collado De Asón - La Sía y Estacas De Trueba por Torrelavega y Espinosa de los Monteros.',
#  'Salinas De Léniz y Arlaban por Vitoria-Gasteiz y Donostia.',
#  'Ixua y Arrate por Zarautz y Ondarroa.',
#  'Monrepós por Huesca y Sabiñánigo.',
#  'Castillo De Loarre por Huesca.',
#  'Collado De Asón - La Sía y La Sía por Ramales de la Victoria.',
#  'Etxauri y Genbe por Pamplona y Irurtzun.',
#  'La Mazorra y Gredilla De Sedano por Medina de Pomar.',
#  'Carmona y Collado De Hoz por Cabezón de la Sal y San Vicente de la Barquera.',
#  'Elgeta y Dima por Durango y Arrasate.',
#  'San Glorio y Dobres-Cucayo por Potes.',
#  'Alto del Repetidor por Vitoria-Gasteiz y Medina de Pomar.',
#  'Salinas De Léniz y Barazar por Vitoria-Gasteiz y Arrasate.',
#  'Moclín y Puerto Lope (Velillos) por Albolote y Íllora.',
#  'Portillo Del Busto y Portillo De Busto por Burgos y Oña.',
#  'Campo Layal (La Aparecida) y Campo Layal por Ramales de la Victoria.',
#  'Balneario De Cardó por Horta de Sant Joan.',
#  'Honduras y Cabezabellosa por Hervás.',
#  'Mendizorrotz y Garate por Donostia y Zarautz.',
#  'Alcomba por Ramales de la Victoria.',
#  'Sierra Salvada por Amurrio.',
#  'Ebo y Margarida por Benirredrà.',
#  'Cerro Malacara por Albolote y Íllora.',
#  'Morcuera y Canencia por Soto del Real y Rascafría.',
#  'Arrebatacapas por El Tiemblo.',
#  'Asterrika y Natxitua por Gernika-Lumo y Bermeo.',
#  'Aracena y Puerto De Cortegana por Aracena y Aroche.',
#  'Eleizalde (Rigoitia) y Rigoitia por Gernika-Lumo.',
#  'Lunada y El Cabrio por Castro-Urdiales y Zalla.',
#  'El Tibidabo y Santa Creu D´Olorda por Barcelona.',
#  'Cruz De La Demanda y Pazuengos por Ezcaray.',
#  'Dima y Aretxabalgane por Durango y Etxebarri.',
#  'Etxaurren por Amurrio.',
#  'Piedrafita y Alto Do Couto por Villafranca del Bierzo.',
#  'Urbasa y Lizarrusti por Tolosa y Altsasu.',
#  'El Tibidabo y Santa Creu D´Olorda por Barcelona.',
#  'Orduña y La Barrerilla por Amurrio y Zuia.',
#  'Orduña y Altube por Amurrio y Zuia.',
#  'San Pelayo y San Pelaio por Gernika-Lumo y Bermeo.',
#  'Elosua - Gorla y Jaizkibel por Donostia y Irun.',
#  'La Granja y Las Muñecas por Castro-Urdiales y Zalla.',
#  'Elosua - Gorla y Jaizkibel por Donostia y Irun.',
#  'Santuario Del Brezo y Santuario Del Brezo por Velilla del Río Carrión.',
#  'Ancares y Lumeras por Villafranca del Bierzo y Cervantes.',
#  'Santa Olaja y Artieta por Valle de Mena.',
#  'Tárbena por Xaló.',
#  ' El Vivero - Ganguren y Aretxabalgane por Etxebarri.',
#  'Cabo Tiñoso por Cartagena.',
#  'Herrera y Rivas De Tereso por Campezo.',
#  'Sanantonzar y Basakabi/Alto De Ezkurra por Donostia y Tolosa.',
#  'La Granja y Las Muñecas por Castro-Urdiales.',
#  'Leaburu por Tolosa.',
#  'Cerro San Cristóbal y Ciudad Encantada por Cuenca.',
#  'Arrebatacapas y El Boquerón por San Lorenzo de El Escorial y El Tiemblo.',
#  'Mendizorrotz y Alkiza por Donostia y Tolosa.',
#  'Izpegi por Baztan.',
#  'El Cargadero y Alto De Vadillo por Covaleda.',
#  'Elgeta y Muniketa por Durango y Gernika-Lumo.',
#  'Moclín y Puerto Lope (Velillos) por Albolote y Íllora.',
#  'Natxitua por Bermeo y Ondarroa.',
#  'San Pedro De Abrisketa y Arraiz por Etxebarri.',
#  'Hoyomenor por Bárcena de Cicero.',
#  'Trabakua y Andikona por Durango.',
#  'Azazeta y Opakua por Vitoria-Gasteiz y Agurain.',
#  'Nª Sª De Oro por Vitoria-Gasteiz y Zuia.',
#  'Azpirotz y Garate por Donostia y Zarautz.',
#  'Ro por Zalla y Valle de Mena.',
#  'Aretxabalgane y Beci por Gernika-Lumo y Zalla.',
#  'Salinas De Léniz y Arlaban por Vitoria-Gasteiz y Arrasate.',
#  'Zollo por Etxebarri.',
#  'Zaldiaran por Vitoria-Gasteiz.',
#  'La Escrita y Seña por Castro-Urdiales y Zalla.',
#  'Salinas De Léniz y Arlaban por Vitoria-Gasteiz y Durango.',
#  'Sant Pere por Benicarló y Alcalà de Xivert.',
#  'La Escrita y Seña por Castro-Urdiales y Ramales de la Victoria.',
#  'Elosua - Gorla y Jaizkibel por Donostia y Irun.',
#  'Ermida por Ourense y Puebla de Sanabria.',
#  'Eleizalde (Rigoitia) y San Pelayo por Gernika-Lumo y Bermeo.',
#  'Udana y Gabiria por Donostia y Arrasate.',
#  'Humaran por Zalla.',
#  'El Tibidabo y Vallençana por Barcelona.',
#  'Golobar y Valberzoso por Reinosa y Aguilar de Campoo.',
#  'El Cerro De San Pedro por Soto del Real y Torrelaguna.',
#  'Loiti por Pamplona.',
#  'Pedroso por Santiago de Compostela.',
#  'Azpirotz y Garate por Donostia y Zarautz.',
#  'La Pedraja por Burgos y Ezcaray.',
#  'Artesiaga y Aniz por Pamplona y Baztan.',
#  'Gabiria y Atagoiti por Tolosa y Ormaiztegi.',
#  'Navasa por Jaca y Sabiñánigo.',
#  'Ro y El Carel por Valle de Mena.',
#  'Pico Almadén por Jaén y Cambil.',
#  'Fonte Da Cova-Collada Trevinca y Fonte Da Cova por O Barco de Valdeorras.',
#  'Ermita De Alba por Lena y Grado.',
#  'Aretxabalgane y Muniketa por Durango y Gernika-Lumo.',
#  'Casielles y La Colladiella por Laviana y Lena.',
#  'Oiz y Muniketa por Durango y Gernika-Lumo.',
#  'Cruz De Barreiros y O Faro por Viveiro y Burela.',
#  'Mondúver y Montdúver por Alzira y Benirredrà.',
#  'El Espino y Encinas Borrachas por Ronda y Cortes de la Frontera.',
#  'Arantzazu y Salinas De Léniz por Vitoria-Gasteiz y Arrasate.',
#  'Font De L´Arbre y Tudons por Alicante y Benidorm.',
#  'San Lorenzo y La Farrapona por Villablino y Teverga.',
#  'Fredes y Vistabella por Benicarló y La Sénia.',
#  'Sta. Mariña Do Monte por Ourense y Maceda.',
#  'Pajares-Cuitu Negru y Pajares por Lena.',
#  'A Torre De San Bartolomeu y A Capela por Betanzos.',
#  'Puerto Camacho y Haza Del Lino por Motril y Órgiva.',
#  'Uitzi y Basakabi/Alto De Ezkurra por Pamplona y Irurtzun.',
#  'Usurbe y Mandubia por Ormaiztegi.',
#  'Coll D´Ares y Port D´Àger por Tremp.',
#  'Mondúver y Montdúver por Benirredrà.',
#  'Cruz De Meira por Castro de Rei y Mondoñedo.',
#  'Karabieta y Ixua por Arrasate.',
#  'Turó De L´Home y Coll De Santa Helena por Sant Celoni.',
#  'Cáñar por Dúrcal y Órgiva.',
#  'La Joya por Málaga y Antequera.',
#  'Peregrí por València y Alzira.',
#  'Odiaga y Ozeka por Amurrio.',
#  'Colladiella y La Colladiella por Laviana y Lena.',
#  'Ouviaña y Chao Da Serra por A Fonsagrada y Ibias.',
#  'Puerto Camacho y Haza Del Lino por Órgiva y Polopos.',
#  'Cástaras por Dúrcal y Órgiva.',
#  'Javalambre y Javalambre (Pico) por Mora de Rubielos.',
#  'Maravio y Marabio por Grado y Teverga.',
#  'Arredondas y As Cales De Bretoña por Castro de Rei y A Pontenova.',
#  "Collfred y Coll De Jou por La Vall d'en Bas.",
#  'Gaucín y El Espino por Estepona y Cortes de la Frontera.',
#  'Padornelo-Alto De Lindín por Mondoñedo.',
#  'La Ragua y Trevélez por Guadix y Dúrcal.',
#  'Tella por Aínsa-Sobrarbe.',
#  'El Sol y Puerto Del Sol por Vélez-Málaga y Colmenar.',
#  'Jesuri por Amurrio.',
#  'La Quesera y La Quesera por Riaza.',
#  'Puerto De Tíscar por Cazorla y Pozo Alcón.',
#  'Garita De Herbeira por Ferrol.',
#  'Cerro Jabalcón por Pozo Alcón.',
#  'Jesuri y Bostarratxeta por Amurrio.',
#  'San Martín por Castro-Urdiales y Zalla.',
#  'Tremuzo por Santiago de Compostela y Noia.',
#  'Andarraso y Cueto Rosales por León y La Robla.',
#  'Erlaitz-Castillo Del Inglés y Castillo Del Inglés por Donostia y Irun.',
#  'Orduña y Peña Angulo por Amurrio y Valle de Mena.',
#  'Collado De Jinquer y Collado De Cuatro Caminos por Onda.',
#  'Mendizorrotz y Etumeta por Donostia.',
#  'Eleizalde (Rigoitia) y Muniketa por Durango y Gernika-Lumo.',
#  'Cristo Do Fiouco por Castro de Rei y Mondoñedo.',
#  'Portillo De Las Batuecas y Paso De Los Lobos-Peña De Francia por La Alberca.',
#  'Garbí por València y Sagunto.',
#  'Tudons y Puerto De Benifallim por Alcoy y Relleu.',
#  'Formigal por Sallent de Gállego.',
#  'Mirador De Ézaro y As Paxareiras por Santa Comba y Carnota.',
#  'O Faro por Viveiro y Burela.',
#  'Javalambre y Javalambre (Pico) por Mora de Rubielos.',
#  'Las Quintanas por Gijón y Oviedo.',
#  'Colladiella y La Colladiella por Oviedo y Siero.',
#  'Cueto Rosales y Olleros De Alba por La Robla.',
#  'Collado Calderón por Ademuz.',
#  'Alto De Encajacabras y Collado De La Traviesa por Villacarrillo y Beas de Segura.',
#  'Calar Alto y Venta Luisa - Calar Alto por Tíjola.',
#  'Txibiarte y Lekamaña por Amurrio y Zuia.',
#  'La Borriqueta y Segura De La Sierra por Santiago-Pontones y Yeste.',
#  'Tárbena y Coll De La Garga por Benidorm y Xaló.',
#  'Karakate y Lizundia por Azkoitia.',
#  'Puerto De El Caballón y Puerto Artafi por Córdoba y Hornachuelos.',
#  'El Madroño y Puerto Del Madroño por Ronda.',
#  'Tella y Bestué por Aínsa-Sobrarbe.',
#  'Garate y Urdaneta por Zarautz.',
#  'Monte Pousadoiro por A Fonsagrada.',
#  'Louseiras-Montouto por Castro de Rei y Mondoñedo.',
#  'Serranillos por Arenas de San Pedro y Burgohondo.',
#  'Xiabre y Monte Do Seixo por Santiago de Compostela y Padrón.',
#  'Iznatoraf por Úbeda y Villacarrillo.',
#  'A Muria por Castro de Rei y A Pontenova.',
#  'Piocorto por Viveiro.',
#  'Mijares y El Piélago por Casavieja.',
#  'Costiña De Canedo por Ourense.',
#  'Xodos y Coll Del Vidre por Cabanes y Albocàsser.',
#  'Aretxabalgane y Sollube por Gernika-Lumo y Bermeo.',
#  'Paxareiras por Betanzos y Aranga.',
#  'Ouviaña y Chao Da Serra por A Fonsagrada y A Pontenova.',
#  'Eulate y Opakua por Valle de Yerri.',
#  'El Remedio por València y Llíria.',
#  'Port D´Àger por Tremp.',
#  'Coll De La Safor y Simat por Alzira y Benirredrà.',
#  'Tibi por Villena y Castalla.',
#  'El Cerro por Hervás.',
#  'Paso De Los Lobos-Peña De Francia y Peña De Francia por La Alberca.',
#  'El Vivero por Etxebarri.',
#  'Ixua y Muniketa por Durango y Arrasate.',
#  'Tentudía y Monasterio De Tentudía por Monesterio y Santa Olalla del Cala.',
#  'Etxauri y San Salvador por Altsasu y Irurtzun.',
#  'Mendizorrotz y Igeldo por Donostia y Zarautz.',
#  'Urkiaga por Pamplona y Baztan.',
#  'Ebo y Tárbena por Xaló.',
#  'Tentudía y Monasterio De Tentudía por Monesterio y Fuentes de León.',
#  'O Porto por Burela.',
#  'Vidré-Vistabella y Coll Del Vidre por Llucena.',
#  'Nogal Del Barranco y Plataforma Del Nogal Del Barranco por Arenas de San Pedro.',
#  'Refugio De Lizara por Jaca.',
#  'Puerto De Las Palomas por Villacarrillo y Cazorla.',
#  'Pozazal por Reinosa y Aguilar de Campoo.',
#  'Salinas De Léniz y Arlaban por Vitoria-Gasteiz y Arrasate.',
#  'O Xalo por Arteixo.',
#  'Cotefablo y Fanlo por Sabiñánigo y Aínsa-Sobrarbe.',
#  'Confrides y Benimantell por Alicante y Benidorm.',
#  'Coves De Canelobre y Puerto De Benifallim por Alcoy y Jijona.',
#  'Arnoate y El Calvario por Ondarroa.',
#  'El León y Puerto De El Colmenar por Málaga y Antequera.',
#  'Parador Nacional "El Adelantado" por Cazorla.',
#  'Gabiria y San Salvador por Altsasu y Ormaiztegi.',
#  'Piedrasluengas y Carmona por Cabezón de la Sal y San Vicente de la Barquera.',
#  'Valle Del Sol por Burgos.',
#  'Aracena y Cortegana por Aracena y Aroche.',
#  'O Castrove por Pontevedra.',
#  'Mijares y Pedro Bernardo por Burgohondo.',
#  'Campello-Portixol y Ermita De Sant Esteve por Alcoy y Ontinyent.',
#  'Portillo De Las Batuecas y Paso De Los Lobos-Peña De Francia por La Alberca.',
#  'San Rafael-Valdelinares y Nogueruelas por Mora de Rubielos.',
#  'Luintra-Nogueira De Ramuin por Ourense y Maceda.',
#  'Aretxabalgane y Elorrieta por Etxebarri y Gorliz.',
#  'Costa Do Vieiro y Monte Penedo Do Boi por Aranga y Xermade.',
#  'O Carazo-Igrexafeita por Ferrol.',
#  'Puerto Viejo y Villamiel por Valverde del Fresno.',
#  'Sancho Leza y Piqueras por Oyón-Oion.',
#  'Aracena y Puerto De Cortegana por Aracena y Aroche.',
#  'Portillo Boca Del Álamo por Jaén y Martos.',
#  'Ermita De Santa Llúcia por Alcalà de Xivert.',
#  'Collado De Hoz y Campo La Cruz por Potes.',
#  'Puerto De Alájar y Santa Ana La Real por Aracena y Fuentes de León.',
#  'Arlaban y Krutzeta por Vitoria-Gasteiz y Arrasate.',
#  'Puerto Del Viento y Puerto De La Calerilla por Ronda y Olvera.',
#  'La Cubilla y Pajares por Lena.',
#  'Formigal y Baños De Panticosa por Sallent de Gállego.',
#  'O Xalo y Santa Locaia por Arteixo.',
#  'Los Álamos por Cartagena.',
#  'Costa Do Vieiro y Monte Penedo Do Boi por Ferrol y Betanzos.',
#  'Torre Miró por La Sénia y Morella.',
#  'Muniketa y Natxitua por Durango y Zarautz.',
#  'Puerto De Las Abejas y Puerto Martínez por Málaga y Cártama.',
#  'Puerto Del Aire por Antequera.',
#  'Perdón-Erreniega y Perdón por Puente la Reina.',
#  'Xodos y Remolcador por Castelló de la Plana y Llucena.',
#  'Salinas De Léniz y Arlaban por Vitoria-Gasteiz y Durango.',
#  'Puerto Lobo y Blancares por Guadix.',
#  "Santuari Del Far por Vic y La Vall d'en Bas.",
#  'Piedrasluengas y Soplao. El por Torrelavega y Cabezón de la Sal.',
#  'Ozeka por Amurrio y Valle de Mena.',
#  'El Navaliegu por Laviana y Lena.',
#  'Paresi y San Pelayo por Bermeo.',
#  'Bidania y Regil por Zarautz y Tolosa.',
#  'La Casilla por Gijón y Villaviciosa.',
#  'Serratella por Alcalà de Xivert y Albocàsser.',
#  'Collado De Los Yesos y Collado De Los Jardines por Jaén y Cambil.',
#  'Peña Negra y Plataforma De Gredos por Piedrahíta.',
#  'Aseginolaza y Urkillaga por Tolosa y Altsasu.',
#  'Jaizkibel y Agiña por Donostia y Irun.',
#  'Monte De Ancos por Ferrol.',
#  'Culou por Noia.',
#  'O Faro y O Cristo De Portapena por Ferrol y Viveiro.',
#  'Cruz De Soto por Riaza.',
#  'Miñide y Campa San Juan por Cangas del Narcea y A Fonsagrada.',
#  'A Áspera por Aranga y Xermade.',
#  'Pena Da Agrela por Santiago de Compostela y Padrón.',
#  'Alto De Encajacabras y Collado De La Traviesa por Villacarrillo y Beas de Segura.',
#  'Puerto Del Zamorano por Morón de la Frontera y Olvera.',
#  'El Bellotar por Yeste y Siles.',
#  'Santa Cecía por Santiago de Compostela.',
#  'Cerro De Los Ángeles por Montroi.',
#  'Gaucín y El Espino por Cortes de la Frontera.',
#  'Portela De Aldarís por Boiro y Padrón.',
#  'Cuetos por Peñamellera Baja.',
#  'Fuentes De Rubielos por València y Llíria.',
#  'Altotero por Burgos.',
#  'El Colladico por València y Sagunto.',
#  'La Borriqueta y El Arguellite por Yeste y Nerpio.',
#  'Salinas De Léniz y Urbasa por Arrasate y Altsasu.',
#  'Elgeta y Lekoitz-Gane por Durango y Arrasate.',
#  'A Capela por Ferrol.',
#  'Cresta Del Gallo y Puerto Del Garruchal por Murcia y Orihuela.',
#  'Ermita De Sant Antoni por Alicante y Alcoy.',
#  'Breamo por Ferrol.',
#  'La Barrerilla y Altube por Amurrio y Zuia.',
#  'Collado De Cieza por Torrelavega y Corvera de Toranzo.',
#  'Sotavento por Ferrol.',
#  'Coll De La Bandereta por Alcalà de Xivert y Cabanes.',
#  'El Bellotar y Puerto De Onsares por Yeste y Siles.',
#  'Rigadas por Zalla.',
#  'Tudons y Puerto De Benifallim por Alcoy y Relleu.',
#  'Aretxabalgane y Muniketa por Durango y Gernika-Lumo.',
#  ' El Vivero - Ganguren y Aretxabalgane por Etxebarri y Gorliz.',
#  'Chiclana De Segura por Úbeda y Villacarrillo.',
#  'Salinas De Léniz y Arlaban por Vitoria-Gasteiz y Arrasate.',
#  'Aia y Andazarrate por Zarautz.',
#  'Arano por Donostia.',
#  'Udana y Gabiria por Ormaiztegi.',
#  'Portixol por Xaló.',
#  'La Quesera y La Quesera por Riaza.',
#  'El Tibidabo y Santa Creu D´Olorda por Barcelona.',
#  'Gabiria y Bidania por Tolosa y Azkoitia.',
#  'Los Alazores y Ochichar por Loja y Albolote.',
#  'Puerto Viejo y Villamiel por Valverde del Fresno.',
#  'Campa San Juan por Cangas del Narcea y A Fonsagrada.',
#  'Las Majadas por Cuenca.',
#  'Montefrío por Loja y Albolote.',
#  'Sollube y Eleizalde por Bermeo.',
#  'Rincón Bello por Alicante y Agost.',
#  'Carmona y Collado De Hoz por Cabezón de la Sal y San Vicente de la Barquera.',
#  'Bianditz y Jaizkibel por Donostia y Irun.',
#  'Alto De Las Solanas y Llombera por León y La Robla.',
#  'Ermita De San Cristóbal por Llucena.',
#  'Santa Locaia y Costa De Barcés por Arteixo.',
#  'Oiz y  El Vivero - Ganguren por Durango y Gernika-Lumo.',
#  'Gaucín y El Espino por Ronda y Cortes de la Frontera.',
#  'Portillo De Las Batuecas y Batuecas por La Alberca.',
#  'Bidania y Aia por Zarautz y Tolosa.',
#  'Alobras por Albarracín.',
#  'Fuente Las Varas y Cruz De Usaño por Ribamontán al Monte.',
#  'Ciudad Encantada y Alto Del Lugar por Cuenca.',
#  'Collado Calderón y Collado De Las Vigas por Requena y Ademuz.',
#  'El Portillo y El Portillo por Valderrobres y Morella.',
#  'Errea y Usetxi por Pamplona y Esteribar.',
#  'Azpirotz y Urkillaga por Tolosa.',
#  'Santuario Del Brezo y Santuario Del Brezo por Velilla del Río Carrión.',
#  'Refugio De Lizara y Fuerte Rapitán por Jaca.',
#  'Urtsua por Baztan.',
#  'Kanpazar y Atxondo por Arrasate.',
#  'El Navaliegu y La Cruz por Oviedo y Siero.',
#  'Augasantas por Santiago de Compostela y Padrón.',
#  'Nuestra Señora De Tremedal y Orihuela por Albarracín.',
#  'Oñatz y Mandubia por Azkoitia.',
#  'Radar De Cullera por València.',
#  'El Portillo y El Portillo por Valderrobres.',
#  'Gaucín y El Espino por Cortes de la Frontera.',
#  'Aia y Andazarrate por Donostia.',
#  'Puerto Lope (Velillos) y Montefrío por Loja y Albolote.',
#  'Artesiaga y Egozkue por Baztan y Esteribar.',
#  'Mandubia y Lizarrusti por Zarautz y Azkoitia.',
#  'Beneixama por Ontinyent y Villena.',
#  'Tentudía y Monasterio De Tentudía por Monesterio y Fuentes de León.',
#  'El Vacar y Cerro Muriano por Córdoba y Obejo.',
#  'Jaizkibel y Fuerte De San Marcos por Donostia y Irun.',
#  'Humaran y Alisedo por Zalla.',
#  'Etxaguen por Vitoria-Gasteiz y Zuia.',
#  'Llombera por La Robla.',
#  'Mont Caro y Vistabella por Benicarló y La Sénia.',
#  'Cerro Muriano por Córdoba y Espiel.',
#  'Collado De Jinquer y Collado De Cuatro Caminos por Onda.',
#  'Aintzioa por Pamplona y Esteribar.',
#  'Canencia y Fresnedillas por Soto del Real y Torrelaguna.',
#  'Puerto De La Reina por Arenas de San Pedro.',
#  'Guirguillano por Puente la Reina y Valle de Yerri.',
#  'Desierto De Las Palmas por Castelló de la Plana y Cabanes.',
#  'Puerto De Las Abejas y Puerto Martínez por Yunquera.',
#  'La Camperona por Oviedo y Siero.',
#  'Bustidoño y Montesclaros por Reinosa.',
#  'Relleu por Alicante y Relleu.',
#  'Etxauri y Genbe por Pamplona y Irurtzun.',
#  'Cabanes por Alcalà de Xivert y Cabanes.',
#  'Salinas De Léniz y Arlaban por Vitoria-Gasteiz y Arrasate.',
#  'Puerto Artafi por Córdoba y Espiel.',
#  'Castroviejo por Nájera.',
#  'La Aldea - Bernedo y Santuario De Codés por Campezo.',
#  'Benagéber (El Sequer) por Requena.',
#  'Ochichar por Loja y Albolote.',
#  'Uitzi y Basakabi/Alto De Ezkurra por Irurtzun.',
#  'Puerto De La Calerilla por Ronda y Olvera.',
#  'Puerto Del Zamorano y Puerto De Los Barrancos Blancos por El Saucejo.',
#  'Aracena y Santa Ana La Real por Aracena y Fuentes de León.',
#  'Ricote y Puerto De Ricote por Murcia.',
#  'Santo Domingo por Zalla.',
#  'Orduña y Peña Angulo por Etxebarri y Amurrio.',
#  'Errea y Usetxi por Pamplona y Esteribar.',
#  'Andikona y Gaztelumendi por Durango.',
#  'Angliru y La Venta´L Aire por Oviedo y Lena.',
#  'Monasterio De Valvanera por Nájera.',
#  'Perdón por Pamplona y Puente la Reina.',
#  'Los Heros por Zalla y Valle de Mena.',
#  'Presa Del Atazar por Torrelaguna.',
#  'Potiche por Riópar.',
#  'Urkarregi (San Miguel) y Itziar por Azkoitia y Ondarroa.',
#  'Ciudad Encantada y Alto Del Lugar por Cuenca.',
#  'Puerto De Tíscar y Puerto De Las Palomas por Jaén y Úbeda.',
#  'Urtsua y Lizarrieta por Baztan.',
#  'Ricote y Puerto De Ricote por Murcia.',
#  'Elosua - Gorla y Endoia por Arrasate y Azkoitia.',
#  'Cerro Negrillo por Hornachuelos.',
#  'El Purche y El Lucero por Dúrcal y Órgiva.',
#  'El Sequén por Murcia y Orihuela.',
#  'Campo Do Pozo por Santa Comba.',
#  'Pesadoira por Noia y Santa Comba.',
#  'Santa María De La Alameda por San Lorenzo de El Escorial.',
#  'Okina por Vitoria-Gasteiz.',
#  'Sojo por Valle de Mena.',
#  'Cocañín por Siero y Villaviciosa.',
#  'Las Muñecas y Talledo por Castro-Urdiales.',
#  'Blancares por Guadix.',
#  'Portillo Del Busto y Portillo De Busto por Oña.',
#  'Iturgoyen por Valle de Yerri.',
#  'Fuente Las Varas y Cruz De Usaño por Bárcena de Cicero y Ribamontán al Monte.',
#  'Arratzain por Donostia.',
#  'Oiz y Ixua por Vitoria-Gasteiz y Durango.',
#  'Balcón De Bizkaia por Gernika-Lumo.',
#  'Uitzi y Basakabi/Alto De Ezkurra por Donostia.',
#  'Alkiza y Orendain por Donostia y Tolosa.',
#  'Jaizkibel y Aritxulegi por Irun.',
#  'Puerto Lope (Velillos) y Montefrío por Loja y Albolote.',
#  'Ebo y Tollos por Xaló.',
#  'Etxauri y San Salvador por Altsasu y Irurtzun.',
#  'Los Braciquios(Barqueros) por Murcia y Alhama de Murcia.',
#  'El Padrún por Oviedo.',
#  'Itziar por Zarautz.',
#  'Udana y Mandubia por Azkoitia y Ormaiztegi.',
#  'Simat por Benirredrà.',
#  'Nuestra Señora De Tremedal y Orihuela por Albarracín.',
#  'El Cordal y El Padrún por Oviedo y Lena.',
#  'Coll De Bot por Valderrobres y Horta de Sant Joan.',
#  'Olleros De Alba por León y La Robla.',
#  'Estacas De Trueba y La Braguía por Torrelavega y Corvera de Toranzo.',
#  'Belate por Baztan.',
#  ' El Vivero - Ganguren y El Vivero por Etxebarri.',
#  'La Horca y Rosales por Medina de Pomar.',
#  'Maigmó por Alicante y Agost.',
#  'Larraitz por Tolosa y Ormaiztegi.',
#  'Albaida por València y Alicante.',
#  'Puerto Alto y El Ronquillo por Santa Olalla del Cala.',
#  'Puerto De La Araña por Morón de la Frontera y Olvera.',
#  'Herrera y Opakua por Vitoria-Gasteiz y Agurain.',
#  'Atxondo y Goiuria por Durango.',
#  'Estacas De Trueba y La Matanela por Medina de Pomar y Espinosa de los Monteros.',
#  'Pajares y El Cordal por Oviedo y León.',
#  'Unbe por Gorliz.',
#  'La Hayuela por Cabezón de la Sal.',
#  'La Almenara por Hornachuelos.',
#  'Puerto Del Garruchal por Murcia y Orihuela.',
#  'Boquete De Zafarraya y El Sol por Colmenar.',
#  'Herrera y La Aldea - Bernedo por Vitoria-Gasteiz y Altsasu.',
#  'Artatza por Vitoria-Gasteiz y Zuia.',
#  'Sorogain por Tolosa.',
#  'Oiz y Gontzegaraigane por Ondarroa.',
#  'Alto De Couso por Ourense y Maceda.',
#  'Peñarroya por Mora de Rubielos.',
#  'Collada De Arnicio por Gijón y Siero.',
#  'Ermita De Pallerols por Benicarló y La Sénia.',
#  'Ravell por Vic.']
